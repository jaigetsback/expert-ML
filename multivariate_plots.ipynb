# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import multivariate_normal

# %%
penguins = pd.read_csv('/Users/jaikumar/Desktop/Berkeley_ML/DataSets_starter1/penguins.csv')

penguins_species = penguins[['species','bill_length_mm','bill_depth_mm']]
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.3+ KB

# %%
penguins_species
# Out:
#     species  bill_length_mm  bill_depth_mm
# 0    Adelie            39.1           18.7
# 1    Adelie            39.5           17.4
# 2    Adelie            40.3           18.0
# 3    Adelie            36.7           19.3
# 4    Adelie            39.3           20.6
# ..      ...             ...            ...
# 328  Gentoo            47.2           13.7
# 329  Gentoo            46.8           14.3
# 330  Gentoo            50.4           15.7
# 331  Gentoo            45.2           14.8
# 332  Gentoo            49.9           16.1
#
# [333 rows x 3 columns]

# %%
penguins_MV = penguins[['bill_length_mm','bill_depth_mm']]

# %%
multivariate_normal?
# Out:
# Signature:       multivariate_normal(mean=None, cov=1, allow_singular=False, seed=None)
# Type:            multivariate_normal_gen
# String form:     <scipy.stats._multivariate.multivariate_normal_gen object at 0x168452650>
# File:            /opt/anaconda3/lib/python3.11/site-packages/scipy/stats/_multivariate.py
# Docstring:
# A multivariate normal random variable.
#
# The `mean` keyword specifies the mean. The `cov` keyword specifies the
# covariance matrix.
#
# Methods
# -------
# pdf(x, mean=None, cov=1, allow_singular=False)
#     Probability density function.
# logpdf(x, mean=None, cov=1, allow_singular=False)
#     Log of the probability density function.
# cdf(x, mean=None, cov=1, allow_singular=False, maxpts=1000000*dim, abseps=1e-5, releps=1e-5, lower_limit=None)  # noqa
#     Cumulative distribution function.
# logcdf(x, mean=None, cov=1, allow_singular=False, maxpts=1000000*dim, abseps=1e-5, releps=1e-5)
#     Log of the cumulative distribution function.
# ...

# %%
mle = multivariate_normal(mean=penguins_MV.mean(), cov=penguins_MV.cov())
print(mle)

# %%
sns.scatterplot(data=penguins,
                x='bill_depth_mm',
                y='bill_length_mm',
                hue='species', 
                style='species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.histplot(data=penguins,x='bill_length_mm')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='bill_depth_mm')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins,
                x='bill_length_mm',
                y='bill_depth_mm')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins,
                x='bill_length_mm',
                y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.kdeplot(data=penguins, 
            x='bill_depth_mm',
            y='bill_length_mm', 
            levels=[.15,.3,.5,.7,.9],
           color='orange')
sns.scatterplot(data=penguins,
                x='bill_depth_mm',
                y='bill_length_mm')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sns.pairplot(penguins, hue='species',diag_kind='kde', kind='scatter')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.jointplot(x = penguins['bill_depth_mm'], y = penguins['bill_length_mm'])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(penguins)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.histplot(data=penguins,x='bill_length_mm')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bill_length_mm', ylabel='Count'>
